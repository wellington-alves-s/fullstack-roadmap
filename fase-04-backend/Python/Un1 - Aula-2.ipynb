# %%
#Estruturas condicionais em Python
1>2

# %%
3>2

# %%
3 == 2

# %%
3 == 3

# %%
a == a

# %%
a = 'aluno'
b = 'aluna'

a is b

# %%
a = 'aluno'
b = 'aluna'

a is not b

# %%
# Estruturas Condicionais if, else, elif
idade = int(input('Digite sua idade: '))
if idade < 18:
    print ('Menor de idade')
elif idade >= 18 and idade < 65:
    print('Adulto')
else:
    print('Idoso')

# %%
idade = 17
if idade < 18:
    print ('Menor de idade')
elif idade >= 18 and idade < 65:
    print('Adulto')
else:
    print('Idoso')

# %%
#Bem vindo à Máquina de venda automatica de ingressos de cinema!

#Solicita a idade do cliente
idade = int(input('Por favor, digite a sua idade: '))

#Verifica a idade para sugestão de filmes
if idade < 12:
    print('Recomendamos você assistir o filme infantil FILME1')
elif idade >= 12 and idade < 18:
    print('Recomendamos você assistir o filme adolescente FILME2')
else:
    print('Recomendamos você assistir o filme adulto FILME3')

#Verifica a disponibilidade de ingressos
quantidade_ingressos = 10 #Suponha que haja 10 ingressos disponíveis
if quantidade_ingressos > 0:
    print('Ingressos estão disponíveis! Divirta-se no cinema!')
else:
    print('Desculpe, todos os ingressos estão esgotados hoje.')
